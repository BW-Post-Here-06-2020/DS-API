# %% [markdown]
# <a href="https://colab.research.google.com/github/tyleretheridge/DS-API/blob/master/notebooks/Modeling_for_BW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ALBERT IMPLEMENTATION

# %%
# %%capture
# !pip install bert-for-tf2
# !pip install sentencepiece

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Model

import bert
from bert.tokenization.bert_tokenization import FullTokenizer

# %% [markdown]
# ## Data Loading

# %% [markdown]
# `train.tsv` and `dev.tsv` are the training and validation sets with 4 columns of data each.
# - `guid`: a generic identifier for each observation derived from the URL the reddit post was retrieved from
# - `label`: an encoded label of each subreddit, from 0 to 1012. Label encoding is mapped in a separate file.
# - `text_b`: an optional field that is currently populated with "a" for all observations. Only used for sequential text classification/prediction.
# - `text_a`: The untokenized text that is to be used for multi-class classification training.
#
# `test.tsv` is a set of data formatted similarly to the `train.tsv` and `dev.tsv` set; however, it only contains `guid` and `text_a` columns.
#
# `encoding_maps` is a csv that contains the corresponding target labels for observations in the training datasets. Generated using sklearn LabelEncoder. Has two columns, `label` and `subreddit`.

# %%
# Import data from .tsv files
train = pd.read_csv('train.tsv', sep='\t', names=['guid','label','text_b','text_a'])
dev = pd.read_csv('dev.tsv', sep='\t', names=['guid','label','text_b','text_a'])
test = pd.read_csv('test.tsv', sep='\t', names=['guid', 'text_a'])

# Load encoding maps
encoding_maps = pd.read_csv('encoding_maps.csv', engine='python')

# %%
train.head()

# %% [markdown]
# ## Tokenization

# %%
import sentencepiece as spm

spm_model = os.path.join(model_dir, "assets", "30k-clean.model")
sp = spm.SentencePieceProcessor()
sp.load(spm_model)
do_lower_case = True

processed_text = bert.albert_tokenization.preprocess_text("Hello, World!", lower=do_lower_case)
token_ids = bert.albert_tokenization.encode_ids(sp, processed_text)

# %% [markdown]
# I think the code below is for a different implementation of BERT, not the one I'm currently using

# %%
# GUID = 'guid'
# DATA_COLUMN = 'text_a'
# LABEL_COLUMN = 'label'

# train_InputExamples = train.apply(lambda x: bert.run_classifier.InputExample(guid=GUID,
#                                                                    text_a = x[DATA_COLUMN], 
#                                                                    text_b = None, 
#                                                                    label = x[LABEL_COLUMN]), axis = 1)
# val_InputExamples = val.apply(lambda x: bert.run_classifier.InputExample(guid=GUID, 
#                                                                    text_a = x[DATA_COLUMN], 
#                                                                    text_b = None, 
#                                                                    label = x[LABEL_COLUMN]), axis = 1)

# %% [markdown]
# ## ALBERT Modeling

# %%
# Write a function to load ALBERT
def load_bert(albert_name):
  """
  Loads ALBERT pretrained model from TFHub
  Input: albert_name (str), 
    name of ALBERT model to load
  Returns: albert_params (dict), 
    loaded params to be used to build model
  """
  model_name = albert_name
  # Fetch ALBERT from TFHub
  albert_dir = bert.fetch_tfhub_albert_model(model_name, ".models")
  # Load ALBERT params
  albert_params = bert.albert_params(model_name)

  # Print status of loaded model
  print("Model Name:", model_name)
  print("Model Directory", model_dir)
  return albert_params

albert_params = load_bert('albert_base')
# Out:
# Fetching ALBERT model: albert_base version: 2
# Already  fetched:  albert_base.tar.gz
# already unpacked at: .models/albert_base
# Model Name: albert_base
# Model Directory .models/albert_base

# %%
# Write a function to build ALBERT model
def build_bert(albert_params):
  """
  Input: dictionary of BERT params
  """
  bert_layer = bert.BertModelLayer.from_params(albert_params, name="albert")
  l_input_ids = keras.layers.Input(shape=(128,), dtype='int32', name="input_ids")
  l_token_type_ids = keras.layers.Input(shape=(128,), dtype='int32', name="token_type_ids")
  output = l_bert([l_input_ids, l_token_type_ids])
  output = keras.layers.Lambda(lambda x: x[:, 0, :])(output)
  output = keras.layers.Dense(2)(output)
  model = keras.Model(inputs=[l_input_ids, l_token_type_ids], outputs=output)

  model.build(input_shape=(None, 128))
  model.compile(optimizer=keras.optimizers.Adam(),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")])

  for weight in l_bert.weights:
      print(weight.name)

  model.summary()  
  return model, bert_layer

# %%
#huggingface

# %% [markdown]
# ## Classification using a Feed-Forward Neural Network
# Adapted from https://www.tensorflow.org/hub/tutorials/tf2_text_classification

# %%
import tensorflow as tf

model = "https://tfhub.dev/google/tf2-preview/nnlm-en-dim128/1"
hub_layer = hub.KerasLayer(model, output_shape=[128], input_shape=[], 
                           dtype=tf.string, trainable=True)

model = tf.keras.Sequential()
model.add(hub_layer)
# Increase nodes in hidden layer
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dense(1013, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_2 (KerasLayer)   (None, 128)               124642688
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_6 (Dense)              (None, 1013)              260341
# =================================================================
# Total params: 125,001,845
# Trainable params: 125,001,845
# Non-trainable params: 0
# _________________________________________________________________

# %%
top_k = tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, 
                                               name='sparse_top_k_categorical_accuracy', 
                                               dtype=None)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name="acc"), top_k])

# %%
model.fit(train['text_a'].values, train['label'].values,
          batch_size=1024,
          epochs=1000)
# Out:
# Epoch 1/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.9207 - acc: 8.7330e-04 - sparse_top_k_categorical_accuracy: 0.0064
# Epoch 2/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.9206 - acc: 0.0012 - sparse_top_k_categorical_accuracy: 0.0058
# Epoch 3/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.9199 - acc: 0.0016 - sparse_top_k_categorical_accuracy: 0.0065
# Epoch 4/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.9191 - acc: 0.0025 - sparse_top_k_categorical_accuracy: 0.0110
# Epoch 5/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.9171 - acc: 0.0051 - sparse_top_k_categorical_accuracy: 0.0137
# Epoch 6/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.9122 - acc: 0.0106 - sparse_top_k_categorical_accuracy: 0.0182
# Epoch 7/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.9101 - acc: 0.0127 - sparse_top_k_categorical_accuracy: 0.0223
# Epoch 8/1000
# 39/39 [==============================] - 6s 150ms/step - loss: 6.9034 - acc: 0.0205 - sparse_top_k_categorical_accuracy: 0.0287
# Epoch 9/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.8962 - acc: 0.0276 - sparse_top_k_categorical_accuracy: 0.0343
# Epoch 10/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.8904 - acc: 0.0334 - sparse_top_k_categorical_accuracy: 0.0398
# Epoch 11/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.8845 - acc: 0.0391 - sparse_top_k_categorical_accuracy: 0.0449
# Epoch 12/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.8784 - acc: 0.0451 - sparse_top_k_categorical_accuracy: 0.0502
# Epoch 13/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.8745 - acc: 0.0489 - sparse_top_k_categorical_accuracy: 0.0535
# Epoch 14/1000
# 39/39 [==============================] - 6s 149ms/step - loss: 6.8708 - acc: 0.0522 - sparse_top_k_categorical_accuracy: 0.0557
# Epoch 15/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.
1000
# 39/39 [==============================] - 6s 149ms/step - loss: 6.7700 - acc: 0.1522 - sparse_top_k_categorical_accuracy: 0.1525
# Epoch 327/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7698 - acc: 0.1522 - sparse_top_k_categorical_accuracy: 0.1525
# Epoch 328/1000
# 39/39 [==============================] - 6s 149ms/step - loss: 6.7691 - acc: 0.1533 - sparse_top_k_categorical_accuracy: 0.1536
# Epoch 329/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7686 - acc: 0.1535 - sparse_top_k_categorical_accuracy: 0.1536
# Epoch 330/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7685 - acc: 0.1536 - sparse_top_k_categorical_accuracy: 0.1536
# Epoch 331/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7684 - acc: 0.1536 - sparse_top_k_categorical_accuracy: 0.1537
# Epoch 332/1000
# 39/39 [==============================] - 6s 149ms/step - loss: 6.7680 - acc: 0.1542 - sparse_top_k_categorical_accuracy: 0.1547
# Epoch 333/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7676 - acc: 0.1544 - sparse_top_k_categorical_accuracy: 0.1549
# Epoch 334/1000
# 39/39 [==============================] - 6s 149ms/step - loss: 6.7675 - acc: 0.1545 - sparse_top_k_categorical_accuracy: 0.1548
# Epoch 335/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7673 - acc: 0.1547 - sparse_top_k_categorical_accuracy: 0.1549
# Epoch 336/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7674 - acc: 0.1547 - sparse_top_k_categorical_accuracy: 0.1549
# Epoch 337/1000
# ...
# Epoch 700/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 701/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 702/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 703/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 704/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 705/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 706/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 707/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 708/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 709/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 710/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1916
# Epoch 711/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 712/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 713/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 714/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 715/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 716/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 717/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 718/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 719/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 720/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 721/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 722/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 723/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 724/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 725/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 726/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 727/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 728/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1916 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 729/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 730/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 731/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 732/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 733/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 734/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 735/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 736/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 737/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 738/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7302 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 739/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 740/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 741/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 742/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 743/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 744/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 745/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 746/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 747/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 748/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 749/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 750/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 751/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 752/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 753/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 754/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 755/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 756/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 757/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7301 - acc: 0.1917 - sparse_top_k_categorical_accuracy: 0.1917
# Epoch 758/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7299 - acc: 0.1922 - sparse_top_k_categorical_accuracy: 0.1923
# Epoch 759/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7293 - acc: 0.1928 - sparse_top_k_categorical_accuracy: 0.1934
# Epoch 760/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7292 - acc: 0.1929 - sparse_top_k_categorical_accuracy: 0.1936
# Epoch 761/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7292 - acc: 0.1930 - sparse_top_k_categorical_accuracy: 0.1936
# Epoch 762/1000
# 39/39 [==============================] - 6s 148ms/step - loss: 6.7287 - acc: 0.1934 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 763/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7290 - acc: 0.1931 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 764/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7286 - acc: 0.1934 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 765/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7284 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 766/1000
# 39/39 [==============================] - 6s 143ms/step - loss: 6.7283 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 767/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7283 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 768/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7283 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 769/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 770/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 771/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 772/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 773/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 774/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 775/1000
# 39/39 [==============================] - 6s 145ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 776/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 777/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 778/1000
# 39/39 [==============================] - 6s 146ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 779/1000
# 39/39 [==============================] - 6s 147ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 780/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 781/1000
# 39/39 [==============================] - 6s 144ms/step - loss: 6.7282 - acc: 0.1936 - sparse_top_k_categorical_accuracy: 0.1937
# Epoch 782/1000
# 17/39 [============>.................] - ETA: 3s - loss: 6.7260 - acc: 0.1958 - sparse_top_k_categorical_accuracy: 0.1959
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d7951b8aa482> in <module>()
#       1 model.fit(train['text_a'].values, train['label'].values,
#       2           batch_size=1024,
# ----> 3           epochs=1000)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# adjust batch size
#model.save
